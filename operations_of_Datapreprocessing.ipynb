# %% [markdown]
# <a href="https://colab.research.google.com/github/saiavinash77/Data-preprocessing-techniques/blob/main/operations_of_Datapreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# this is the dataset link
#
# https://uc252744c5311e3b10e5df0f2a42.dl.dropboxusercontent.com/cd/0/get/Cm7wP5k0w0cWc1f-vWyhypR7DIkunu6Ufs_Xwh1l5_VRhCHaQDtb6dMqwJfdeblys0nVeXvzVTwGb0n-XXlBZDxj5uxAx6NctcoR6iV_1TvsZbbXxiQ53SIX6Ydxuhe7dycHfqUfn3eV-NqAA-0-_Dss4dXoh2g-cbs2jlE5TNpppA/file?_download_id=9403959997744551538995690032185175826331756958764112136525281891&_log_download_success=1&_notify_domain=www.dropbox.com&dl=1

# %%
#  this is the dataset im worked with
# https://uc252744c5311e3b10e5df0f2a42.dl.dropboxusercontent.com/cd/0/get/Cm7wP5k0w0cWc1f-vWyhypR7DIkunu6Ufs_Xwh1l5_VRhCHaQDtb6dMqwJfdeblys0nVeXvzVTwGb0n-XXlBZDxj5uxAx6NctcoR6iV_1TvsZbbXxiQ53SIX6Ydxuhe7dycHfqUfn3eV-NqAA-0-_Dss4dXoh2g-cbs2jlE5TNpppA/file?_download_id=9403959997744551538995690032185175826331756958764112136525281891&_log_download_success=1&_notify_domain=www.dropbox.com&dl=1

# %%
#loading the dependencies whatever we want to begin

import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# # **Data Collection**-**Analysis**

# %%
diabeties_dataset = pd.read_csv("/content/diabetes.csv")

# %%
print(diabeties_dataset)
# Out:
#      Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0              6      148             72  ...                     0.627   50        1
# 1              1       85             66  ...                     0.351   31        0
# 2              8      183             64  ...                     0.672   32        1
# 3              1       89             66  ...                     0.167   21        0
# 4              0      137             40  ...                     2.288   33        1
# ..           ...      ...            ...  ...                       ...  ...      ...
# 763           10      101             76  ...                     0.171   63        0
# 764            2      122             70  ...                     0.340   27        0
# 765            5      121             72  ...                     0.245   30        0
# 766            1      126             60  ...                     0.349   47        1
# ...

# %%
diabeties_dataset.shape
# Out:
# (768, 9)

# %%
# printing the first 5 rows
diabeties_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  ...   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72             35  ...  33.6                     0.627   50        1
# 1            1       85             66             29  ...  26.6                     0.351   31        0
# 2            8      183             64              0  ...  23.3                     0.672   32        1
# 3            1       89             66             23  ...  28.1                     0.167   21        0
# 4            0      137             40             35  ...  43.1                     2.288   33        1
#
# [5 rows x 9 columns]

# %% [markdown]
# here we are the target is outcome which means 0 or 1 .
#
# 0------>non-diabetic.
#
# 1------>diabetic.

# %%
diabeties_dataset.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ## **Counting  how many people are diabetiic and non-diabetic**

# %%
diabeties_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diabeties_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  ...        BMI  DiabetesPedigreeFunction        Age
# Outcome                                          ...
# 0           3.298000  109.980000      68.184000  ...  30.304200                  0.429734  31.190000
# 1           4.865672  141.257463      70.824627  ...  35.142537                  0.550500  37.067164
#
# [2 rows x 8 columns]

# %%
X=diabeties_dataset.drop(columns = 'Outcome',axis=1 )
Y=diabeties_dataset['Outcome']

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0              6      148             72  ...  33.6                     0.627   50
# 1              1       85             66  ...  26.6                     0.351   31
# 2              8      183             64  ...  23.3                     0.672   32
# 3              1       89             66  ...  28.1                     0.167   21
# 4              0      137             40  ...  43.1                     2.288   33
# ..           ...      ...            ...  ...   ...                       ...  ...
# 763           10      101             76  ...  32.9                     0.171   63
# 764            2      122             70  ...  36.8                     0.340   27
# 765            5      121             72  ...  26.2                     0.245   30
# 766            1      126             60  ...  30.1                     0.349   47
# ...

# %%
Y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# # **DATA STANDARDISATION**

# %%
scaling = StandardScaler()   # IMPORTING THE MODULE IN scaling attribute
scaling.fit(X)                   #fitting all the parameters to learn it .
standard_data = scaling.transform(X)# now its time to work it as effieciently by getting all the data .

# %%
print(standard_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %% [markdown]
# # **SPLITTING AFTER STANDARDISING THE DATA **

# %%
X = standard_data
Y = diabeties_dataset['Outcome']

# %%
print(X)
print(Y)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# # **TRAINING TESTING PART**

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.3,random_state = 2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (768, 8) (537, 8) (231, 8)

# %% [markdown]
# # **my rough work**

# %% [markdown]
# # **AGAIN   PRACTISING**,,..................

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("/content/diabetes.csv")

# %%
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0              6      148             72  ...                     0.627   50        1
# 1              1       85             66  ...                     0.351   31        0
# 2              8      183             64  ...                     0.672   32        1
# 3              1       89             66  ...                     0.167   21        0
# 4              0      137             40  ...                     2.288   33        1
# ..           ...      ...            ...  ...                       ...  ...      ...
# 763           10      101             76  ...                     0.171   63        0
# 764            2      122             70  ...                     0.340   27        0
# 765            5      121             72  ...                     0.245   30        0
# 766            1      126             60  ...                     0.349   47        1
# ...

# %%
dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
X=dataset.drop(columns = 'Outcome',axis = 1)
Y = dataset['Outcome']

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0              6      148             72  ...  33.6                     0.627   50
# 1              1       85             66  ...  26.6                     0.351   31
# 2              8      183             64  ...  23.3                     0.672   32
# 3              1       89             66  ...  28.1                     0.167   21
# 4              0      137             40  ...  43.1                     2.288   33
# ..           ...      ...            ...  ...   ...                       ...  ...
# 763           10      101             76  ...  32.9                     0.171   63
# 764            2      122             70  ...  36.8                     0.340   27
# 765            5      121             72  ...  26.2                     0.245   30
# 766            1      126             60  ...  30.1                     0.349   47
# ...

# %%
Y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
scaling = StandardScaler()

# %%
scaling.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaling.transform(X)

# %%
standardized_data
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
X = standardized_data
Y = dataset['Outcome']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.3,random_state = 2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (768, 8) (537, 8) (231, 8)
